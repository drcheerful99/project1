# %%
# import libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# import dataFrame
from Data_prep_py import *
from matplotlib import rcParams
# Out:
# C:\Users\Arthur\Documents\Hopkins.repos\project1\Data_prep_py.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tsa_numbered_nyt["Total Cases"] = tsa_numbered_nyt.groupby(["Date"])["cases"].transform("sum")
# C:\Users\Arthur\Documents\Hopkins.repos\project1\Data_prep_py.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   California["Case Rate of Change"]= California["cases"].diff()
# C:\Users\Arthur\Documents\Hopkins.repos\project1\Data_prep_py.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Georgia["Case Rate of Change"]= Georgia["cases"].diff()
# C:\Users\Arthur\Documents\Hopkins.repos\project1\Data_prep_py.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Massachusetts["Case Rate of Change"]= Massachusetts["cases"].diff()
# C:\Users\Arthur\Documents\Hopkins.repos\project1\Data_prep_py.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Texas["Case Rate of Change"]= Texas["cases"].diff()

# %%
# reformat date for plot
# nyt_nationwide['Date'] = pd.to_datetime(nyt_nationwide['Date'], format = '%m/%d/%Y')

nyt_nationwide['Date'] = pd.to_datetime(nyt_nationwide['Date'], format='%Y%m%d')
nyt_nationwide.head()
# Out:
#           Date  Total Cases  Case Rate of Change
# 240 2020-03-01           88                  NaN
# 253 2020-03-02          104                 16.0
# 268 2020-03-03          125                 21.0
# 284 2020-03-04          161                 36.0
# 301 2020-03-05          228                 67.0

# %%
# plot total cases change over time 
# create lists for x_axis (date) and y_axis(total cases)
x = nyt_nationwide['Date'].tolist()
y = nyt_nationwide['Total Cases'].tolist()
y_change = nyt_nationwide['Case Rate of Change'].tolist()

plt.figure(figsize = (8, 6))
plt.plot(x, y, color = 'blue')
plt.ticklabel_format(axis="y", style="plain")
plt.show()

# %%
# plot case rate changes  over time 
# create lists for x_axis (date) and y_axis(total cases)
x = nyt_nationwide['Date'].tolist()
# y = nyt_nationwide['Total Cases'].tolist()
y_change = nyt_nationwide['Case Rate of Change'].tolist()

plt.figure(figsize = (8, 6))
plt.plot(x, y_change, color = 'blue')
plt.title('Case Rate of Change Over Time')
plt.xlabel('Date')
plt.ylabel('Case Rate')
plt.grid(alpha = 0.5)
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(x, y, color = 'red')
plt.plot(x, y_change, color = 'blue')
plt.show()
