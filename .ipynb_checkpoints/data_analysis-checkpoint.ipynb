# %%
#import dependencies
import matplotlib.pyplot as plt
import pandas as pd
from final_data_prep_py import *
import datetime as dt
from matplotlib import rcParams
import scipy
from scipy import stats
# Out:
# C:\Users\jekor\Desktop\project1\final_data_prep_py.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tsa_numbered_nyt["Total Cases"] = tsa_numbered_nyt.groupby(["Date"])["cases"].transform("sum")
# C:\Users\jekor\Desktop\project1\final_data_prep_py.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   California["Case Rate of Change"]= California["cases"].diff()
# C:\Users\jekor\Desktop\project1\final_data_prep_py.py:73: SettingWithCopyWarning:
# ...

# %%
# Total Traveler Throughput 2020 comparing date to moving average of traveler numbers
rcParams['figure.figsize'] = 14,12
date = tsa['Date']
travelers_2020 = tsa['Average 2020']
plt.plot(date,travelers_2020, color='r', linewidth=1, markersize=5, label='Travelers 2020', linestyle='-')
plt.title('7 Day Moving Average of Traveler Numbers Throughout 2020',fontsize = 24)
plt.xlabel('Date',fontsize = 14)
plt.ylabel('Traveler Numbers',fontsize = 14)
plt.ticklabel_format(axis='y',style='plain')
plt.legend(loc='best')
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/traveler_numbers2020.png")
plt.show()

# %%
# comparing 2020 to 2019
rcParams['figure.figsize'] = 14,12
date = tsa['Date']
travelers_2020 = tsa['Average 2020']
plt.plot(date,travelers_2020, color='r', markersize=5, label='Travelers 2020', linestyle='-')
travelers_2019 = tsa['Average 2019']
plt.plot(date,travelers_2019, color='g', linewidth=1, markersize=5, label='Travelers 2019', linestyle='-')
plt.title('7 Day Moving Average of Traveler Numbers Throughout 2019 VS. 2020',fontsize = 24)
plt.xlabel('Date',fontsize = 14)
plt.ylabel('Traveler Numbers',fontsize = 14)
plt.ticklabel_format(axis='y',style='plain')
plt.legend(loc='best')
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/traveler_numbers2019_vs_2020.png")
plt.show()

# %%
# Total Traveler Throughput 2020
rcParams['figure.figsize'] = 14,12
date = nyt_nationwide['DateFormat']
case_numbers = nyt_nationwide["Total Cases"]
plt.plot(date,case_numbers, color='r', linewidth=1, markersize=5, label='Case Numbers', linestyle='-')
plt.title('Case Numbers Throughout 2020',fontsize = 24)
plt.xlabel('Date',fontsize = 14)
plt.ylabel('Case Numbers',fontsize = 14)
plt.ticklabel_format(axis='y',style='plain')
plt.legend(loc='best')
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/case_numbers2020.png")
plt.show()

# %%
# Total Traveler Throughput 2020
rcParams['figure.figsize'] = 14,12
date = nyt_nationwide['DateFormat']
roc = nyt_nationwide["Averaged Rate of Change"]
plt.plot(date,roc, color='r', linewidth=1, markersize=5, label='7 Day Moving Average of Case Numbers', linestyle='-')
plt.title('7 Day Moving Average of the Daily Rate of Change in Case Numbers Throughout 2020',fontsize = 22)
plt.xlabel('Date',fontsize = 14)
plt.ylabel('7 Day Moving Average of the Daily Rate of Change in Case Numbers',fontsize = 14)
plt.ticklabel_format(axis='y',style='plain')
plt.legend(loc='best')
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/nationroc2020.png")
plt.show()

# %%
#implement  for loop to track correlations along different time shifts and find strongest correlation.  Iterate through columns, skipping first
#append data to lists for tracking purposes
best_correlation=0
correlations= []
case_day_shift= []
counter=0

for i in correlation_total_data:
    if counter<2:
        counter+=1
        continue
    current_corr = correlation_total_data["Average 2020"].corr(correlation_total_data[i])
    if (current_corr * current_corr) > (best_correlation*best_correlation):
        best_correlation=current_corr
        best_lag = i
    correlations.append(current_corr)
    case_day_shift.append(i)

# %%
best_correlation
# Out:
# 0.47565576483079886

# %%
best_lag
# Out:
# 20

# %%
correlations
# Out:
# [0.1413959668926873,
#  0.1458726738282651,
#  0.14793652257045653,
#  0.1463225411663827,
#  0.14086638953300626,
#  0.13199147433578906,
#  0.1191763538790159,
#  0.10305104874596549,
#  0.08485437675554829,
#  0.06523874510552405,
#  0.04280640621224783,
#  0.018384284333755507,
#  -0.0076845535952321025,
#  -0.03377512593910756,
#  -0.0595911625800677,
#  -0.08529934252703611,
#  -0.11043287840073972,
#  -0.13419657398661894,
#  -0.15609925299533964,
#  -0.17568612911507375,
#  -0.19288532651229318,
#  -0.20756254151239328,
#  -0.21970765985077806,
#  -0.22944775832259626,
#  -0.23695165602069718,
#  -0.24226477852927772,
#  -0.2455645311093315,
#  -0.2469734393437783,
#  -0.24668136823450962,
#  -0.24488617901107607,
#  -0.21381334986264133,
#  -0.18912757227101917,
#  -0.16176419197879802,
#  -0.1310359605721109,
#  -0.09689333066788537,
#  -0.05859883906865443,
#  -0.01628882285238048,
#  0.031002516272660437,
#  0.08296909616594755,
#  0.1394758574342426,
# ...

# %%
#graph showing the correlations along the time shift
rcParams['figure.figsize'] = 14,12
plt.bar(case_day_shift,correlations)
plt.title("The Relationship Between the 7 Day Moving Average of Case Numbers Rate of Change and 7 Day Moving Average Traveler Numbers")
plt.xlabel("The Date Difference Between the Average of Case Numbers Rate of Change and  7 Day Moving Average Traveler Numbers with Respect to Average Numbers ROC")
plt.ylabel("The Correlation Coefficient")
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Relationship Strength_Correlation")

# %%
#visual comparion at original date matchup
plt.plot(combined_total_data["DateFormat"],combined_total_data["Average 2020"],label="Travel Numbers")
plt.plot(combined_total_data["DateFormat"],combined_total_data["Averaged Rate of Change"],label="Case Rate of Change")
plt.ticklabel_format(axis='y',style='plain')
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Traveler Numbers and Case Number Rate of Change", fontsize = 14)
plt.title("A Look at the Relationship Between Traveler Numbers and Case Numbers")
plt.grid()
plt.tight_layout()
plt.legend()
plt.savefig("Graphs/Numbers Comparison Visual")

# %%
rcParams['figure.figsize'] = 14,12
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Date')
ax1.set_ylabel('Travel Numbers', color=color)
ax1.plot(combined_total_data["DateFormat"],combined_total_data["Average 2020"], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Rate of change of Case Numbers', color=color)
ax2.plot(combined_total_data["DateFormat"],combined_total_data["Averaged Rate of Change"], color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.ticklabel_format(axis='y',style='plain')
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Traveler Numbers and Case Number Rate of Change", fontsize = 14)
plt.title("A Look at the Relationship Between Traveler Numbers and Case Numbers", fontsize = 20)
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Not to scale NCV")

# %%
#graphs on individual state data
rcParams['figure.figsize'] = 14,12
plt.plot(California["DateFormat"],California["cases"],color='r',label="California")
plt.title("Total Number of Cases in California",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Total Cases",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/California_Total_Cases.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(California["DateFormat"],California["Averaged Rate of Change"],color='r',label="California")
plt.title("Case  Numbers Daily Rate of Change of the 7 Day Moving Average in California",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Daily Rate of Change of the 7 Day Moving Average",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/California_Cases_over_Time.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(Georgia["DateFormat"],Georgia["cases"],color='b',label="Georgia")
plt.title("Total Number of Cases in Georgia",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Total Cases",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Georgia_Total_Cases.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(Georgia["DateFormat"],Georgia["Averaged Rate of Change"],color='b',label="Georgia")
plt.title("Case Numbers Daily Rate of Change of the 7 Day Moving Average in Georgia",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Daily Rate of Change of the 7 Day Moving Average",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Georgia_Cases_over_Time.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(Massachusetts["DateFormat"],Massachusetts["cases"],color='g',label="Massachusetts")
plt.title("Total Number of Cases in Massachusetts",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Total Cases",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Massachusetts_Total_Cases.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(Massachusetts["DateFormat"],Massachusetts["Averaged Rate of Change"],color='g',label="Massachusetts")
plt.title("Case Numbers Daily Rate of Change of the 7 Day Moving Average in Massachusetts",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Daily Rate of Change of the 7 Day Moving Average",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Massachusetts_Cases_over_Time.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(Texas["DateFormat"],Texas["cases"],color='y',label="Texas")
plt.title("Total Number of Cases in Texas",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Total Cases",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Texas_Total_Cases.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(Texas["DateFormat"],Texas["Averaged Rate of Change"],color='y',label="Texas")
plt.title("Case Numbers Daily Rate of Change of the 7 Day Moving Average in Texas",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("Daily Rate of Change of the 7 Day Moving Average",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Texas_Cases_over_Time.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(California["DateFormat"],California["cases"],color='r',label="California")
plt.plot(Georgia["DateFormat"],Georgia["cases"],color='b',label="Georgia")
plt.plot(Massachusetts["DateFormat"],Massachusetts["cases"],color='g',label="Massachusetts")
plt.plot(Texas["DateFormat"],Texas["cases"],color='y',label="Texas")
plt.title("Total Number of Cases in Four Different States")
plt.xlabel("Date")
plt.ylabel("Total Cases")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Total_Cases_Comparison.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(California["DateFormat"],California["Averaged Rate of Change"],color='r',label="California")
plt.plot(Georgia["DateFormat"],Georgia["Averaged Rate of Change"],color='b',label="Georgia")
plt.plot(Massachusetts["DateFormat"],Massachusetts["Averaged Rate of Change"],color='g',label="Massachusetts")
plt.plot(Texas["DateFormat"],Texas["Averaged Rate of Change"],color='y',label="Texas")
plt.title("Case Numbers Daily Rate of Change of the 7 Day Moving Average in Four Different States")
plt.xlabel("Date")
plt.ylabel("Case Rate of Change")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Rate_of_Change_Comparison.png")

# %% [markdown]
# Looking at the above graphs in comparison, it looks obvious that Texas And California were hit much harder by COVID.  However, this data does not account for differences in population size or in population density.  A much better complete analysis would also cover both metrics with respect to population.

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(California["DateFormat"],California["Case Percent"],color='r',label="California")
plt.plot(Georgia["DateFormat"],Georgia["Case Percent"],color='b',label="Georgia")
plt.plot(Massachusetts["DateFormat"],Massachusetts["Case Percent"],color='g',label="Massachusetts")
plt.plot(Texas["DateFormat"],Texas["Case Percent"],color='y',label="Texas")
plt.title("Percent of Total Cases in Four Different States")
plt.xlabel("Date")
plt.ylabel("Percent of Total Cases")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Percent_of_Total_Cases_Comparison.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(California["DateFormat"],California["Percent Rate of Change"],color='r',label="California")
plt.plot(Georgia["DateFormat"],Georgia["Percent Rate of Change"],color='b',label="Georgia")
plt.plot(Massachusetts["DateFormat"],Massachusetts["Percent Rate of Change"],color='g',label="Massachusetts")
plt.plot(Texas["DateFormat"],Texas["Percent Rate of Change"],color='y',label="Texas")
plt.title("The 7 Day Moving Average of The Daily Number Percent Change in Four Different States")
plt.xlabel("Date")
plt.ylabel("The Daily Number Percent Change")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Percent_Change_Comparison.png")

# %%
#individual state proc
rcParams['figure.figsize'] = 14,12
plt.plot(California["DateFormat"],California["Percent Rate of Change"],color='g',label="California")
plt.title("Moving Average of the Percent Rate of Change in Cases in California",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Rate of Change in Cases in California",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/CA_PROC.png")

# %%
#individual state proc
rcParams['figure.figsize'] = 14,12
plt.plot(Texas["DateFormat"],Texas["Percent Rate of Change"],color='k',label="Texas")
plt.title("Moving Average of the Percent Rate of Change in Cases in Texas",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Rate of Change in Cases in Texas",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/TX_PROC.png")

# %%
#individual state proc
rcParams['figure.figsize'] = 14,12
plt.plot(Georgia["DateFormat"],Georgia["Percent Rate of Change"],color='r',label="Georgia")
plt.title("Moving Average of the Percent Rate of Change in Cases in Georgia",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Rate of Change in Cases in Georgia",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/GA_PROC.png")

# %%
#individual state proc
rcParams['figure.figsize'] = 14,12
plt.plot(Massachusetts["DateFormat"],Massachusetts["Percent Rate of Change"],color='b',label="Massachusetts")
plt.title("Moving Average of the Percent Rate of Change in Cases in Massachusetts",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Rate of Change in Cases in Massachusetts",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/MA_PROC.png")

# %%
#individual airport metrics
rcParams['figure.figsize'] = 14,12
plt.plot(LAX["DateFormat"],LAX["Averaged POB"],color='y',label="LAX")
plt.title("7 Day Moving Average of the Percent Baseline of Travelers at LAX",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Baseline of Travelers",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/LAX_POB.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(SFO["DateFormat"],SFO["Averaged POB"],color='g',label="SFO")
plt.title("7 Day Moving Average of the Percent Baseline of Travelers at SFO",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Baseline of Travelers",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/SFO_POB.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(BOS["DateFormat"],BOS["Averaged POB"],color='b',label="BOS")
plt.title("7 Day Moving Average of the Percent Baseline of Travelers at BOS",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Baseline of Travelers",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/BOS_POB.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(ATL["DateFormat"],ATL["Averaged POB"],color='r',label="ATL")
plt.title("7 Day Moving Average of the Percent Baseline of Travelers at ATL",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Baseline of Travelers",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/ATL_POB.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(DFW["DateFormat"],DFW["Averaged POB"],color='k',label="DFW")
plt.title("7 Day Moving Average of the Percent Baseline of Travelers at DFW",fontsize = 24)
plt.xlabel("Date",fontsize = 14)
plt.ylabel("7 Day Moving Average of the Percent Baseline of Travelers",fontsize = 14)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/DFW_POB.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(LAXCA["DateFormat_x"],LAXCA["Percent Rate of Change"],color='m',label="California")
plt.plot(SFOCA["DateFormat_x"],SFOCA["Percent Rate of Change"],color='m',label="California")
plt.plot(ATLGA["DateFormat_x"],ATLGA["Percent Rate of Change"],color='c',label="Georgia")
plt.plot(BOSMA["DateFormat_x"],BOSMA["Percent Rate of Change"],color='g',label="Massachusetts")
plt.plot(DFWTX["DateFormat_x"],DFWTX["Percent Rate of Change"],color='y',label="Texas")
plt.title("The 7 Day Moving Average of The Daily Number Percent Change in Four Different States")
plt.xlabel("Date")
plt.ylabel("The Daily Number Percent Change")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Airport_Percent_Change_Comparison.png")

# %%
rcParams['figure.figsize'] = 14,12
plt.plot(LAXCA["DateFormat_x"],LAXCA["Averaged POB"],color='b',label="California")
plt.plot(SFOCA["DateFormat_x"],SFOCA["Averaged POB"],color='r',label="California")
plt.plot(ATLGA["DateFormat_x"],ATLGA["Averaged POB"],color='c',label="Georgia")
plt.plot(BOSMA["DateFormat_x"],BOSMA["Averaged POB"],color='g',label="Massachusetts")
plt.plot(DFWTX["DateFormat_x"],DFWTX["Averaged POB"],color='y',label="Texas")
plt.title("The 7 Day Moving Average of Airport Percent of Baseline in Traffic Data in Five Different States")
plt.xlabel("Date")
plt.ylabel("The Daily Number Percent Change")
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("Graphs/Airport_POB_Comparison.png")

# %%
#correlation between airport passenger number percent of baseline and case rate of change percent for all 5 examples
LAXCA["Averaged POB"].corr(LAXCA["Percent Rate of Change"])
# Out:
# 0.3654015803655963

# %%
SFOCA["Averaged POB"].corr(SFOCA["Percent Rate of Change"])
# Out:
# 0.07025267263555282

# %%
BOSMA["Averaged POB"].corr(BOSMA["Percent Rate of Change"])
# Out:
# -0.3712230903341663

# %%
DFWTX["Averaged POB"].corr(DFWTX["Percent Rate of Change"])
# Out:
# 0.6690129615617237

# %%
ATLGA["Averaged POB"].corr(ATLGA["Percent Rate of Change"])
# Out:
# 0.10483143844308312

# %%
#2 sample t test to test null hypothesis that 2020 and 2019 traveler data is same
scipy.stats.ttest_ind(tsa.dropna()["Average 2019"],tsa.dropna()["Average 2020"],equal_var = False)
# Out:
# Ttest_indResult(statistic=74.8789734738697, pvalue=4.214736211210397e-213)
