# %%
# import libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# import dataFrame
from final_data_prep_py import *

# %%
# reformat date for plot
# nyt_nationwide['Date'] = pd.to_datetime(nyt_nationwide['Date'], format = '%m/%d/%Y')

nyt_nationwide['Date'] = pd.to_datetime(nyt_nationwide['Date'], format='%Y%m%d')
LAX['Date'] = pd.to_datetime(LAX['Date'], format='%Y%m%d')
SFO['Date'] = pd.to_datetime(SFO['Date'], format='%Y%m%d')
BOS['Date'] = pd.to_datetime(BOS['Date'], format='%Y%m%d')
ATL['Date'] = pd.to_datetime(ATL['Date'], format='%Y%m%d')
DFW['Date'] = pd.to_datetime(DFW['Date'], format='%Y%m%d')
LAX.head()
# Out:
# <ipython-input-100-993d3ff530c6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LAX['Date'] = pd.to_datetime(LAX['Date'], format='%Y%m%d')
# <ipython-input-100-993d3ff530c6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SFO['Date'] = pd.to_datetime(SFO['Date'], format='%Y%m%d')
# <ipython-input-100-993d3ff530c6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# plot total cases change over time 
# create lists for x_axis (date) and y_axis(total cases)
x_base = nyt_nationwide['Date'].tolist()
y = nyt_nationwide['Total Cases'].tolist()
# y_change = nyt_nationwide['Case Rate of Change'].tolist()

plt.figure(figsize = (14, 12))
plt.plot(x_base, y, color = 'blue', label = 'Total Cases through July, 2020', linewidth = 1)
plt.ticklabel_format(axis="y", style="plain")
plt.title('Total Cases Over Time', fontsize = 24, pad = 20)
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.grid(alpha = 0.75)
plt.legend(loc = 'best')
plt.tight_layout()
plt.show()

# %%
# plot case rate changes  over time 
# create lists for x_axis (date) and y_axis(total cases)
x = nyt_nationwide['Date'].tolist()
# y = nyt_nationwide['Total Cases'].tolist()
y_change = nyt_nationwide['Case Rate of Change'].tolist()


plt.figure(figsize = (14, 12))
plt.plot(x, y_change, color = 'blue', label = 'Case Rate of Changes', linewidth = 1)
plt.ticklabel_format(axis="y", style="plain")

# plt.plot(x, y_mean, color = 'red', label = 'Case Rate of Changes', linewidth = 1)

plt.title('Case Rate of Change Over Time', fontsize = 24, pad = 20)
plt.xlabel('Date')
plt.ylabel('Case Rate')
plt.legend(loc = 'best')
plt.grid(alpha = 0.75)
plt.show()

# %%
# airport for LAX
# plot case rate changes  over time 
# create lists for x_axis (date) and y_axis(total cases)
x = LAX['Date'].tolist()
y_lax = LAX['PercentOfBaseline'].tolist()

plt.figure(figsize = (14, 12))
# plt.plot(x_base, y, color = 'blue', label = 'Total Cases through July, 2020', linewidth = 1)

plt.plot(x, y_lax, color = 'blue', label = '% change of baseline at LAX', linewidth = 1)

plt.ticklabel_format(axis="y", style="plain")

# plt.plot(x, y_mean, color = 'red', label = 'Case Rate of Changes', linewidth = 1)

plt.title('PercentOfBaseline', fontsize = 24, pad = 20)
plt.xlabel('Date')
plt.ylabel('% change of baseline')
plt.legend(loc = 'best')
plt.grid(alpha = 0.75)
plt.show()

# %%
# airport for SFO
# plot case rate changes  over time 
x = SFO['Date'].tolist()
y_sfo = SFO['PercentOfBaseline'].tolist()

plt.figure(figsize = (14, 12))
plt.plot(x, y_sfo, color = 'red', label = '% change of baseline over time', linewidth = 1)
plt.ticklabel_format(axis="y", style="plain")
plt.title('PercentOfBaseline', fontsize = 24, pad = 20)
plt.xlabel('Date')
plt.ylabel('% change of baseline')
plt.legend(loc = 'best')
plt.grid(alpha = 0.75)
plt.show()

# %%
# airport for BOS
# plot case rate changes  over time 

x = BOS['Date'].tolist()
y_bos = BOS['PercentOfBaseline'].tolist()
plt.figure(figsize = (14, 12))
plt.plot(x, y_bos, color = 'red', label = '% change of baseline over time', linewidth = 1)
plt.ticklabel_format(axis="y", style="plain")
plt.title('PercentOfBaseline', fontsize = 24, pad = 20)
plt.xlabel('Date')
plt.ylabel('% change of baseline')
plt.legend(loc = 'best')
plt.grid(alpha = 0.75)
plt.show()

# %%
# airport for ATL
# plot case rate changes  over time 
x = ATL['Date'].tolist()
y_atl = ATL['PercentOfBaseline'].tolist()
plt.figure(figsize = (14, 12))
plt.plot(x, y_atl, color = 'red', label = '% change of baseline over time', linewidth = 1)
plt.ticklabel_format(axis="y", style="plain")
plt.title('PercentOfBaseline', fontsize = 24, pad = 20)
plt.xlabel('Date')
plt.ylabel('% change of baseline')
plt.legend(loc = 'best')
plt.grid(alpha = 0.75)
plt.show()

# %%
# airport for DFW

x = DFW['Date'].tolist()
y_dfw = DFW['PercentOfBaseline'].tolist()

plt.figure(figsize = (14, 12))
plt.plot(x, y_dfw, color = 'red', label = '% change of baseline over time', linewidth = 1)
plt.ticklabel_format(axis="y", style="plain")
plt.title('PercentOfBaseline', fontsize = 24, pad = 20)
plt.xlabel('Date')
plt.ylabel('% change of baseline')
plt.legend(loc = 'best')
plt.grid(alpha = 0.75)
plt.show()

# %%
# airports 

x = LAX['Date'].tolist()
# y = nyt_nationwide['Total Cases'].tolist()
y_lax = LAX['PercentOfBaseline'].tolist()
# y_sfo = SFO['PercentOfBaseline'].tolist()
# y_bos = BOS['PercentOfBaseline'].tolist()
y_atl = ATL['PercentOfBaseline'].tolist()
y_dfw = DFW['PercentOfBaseline'].tolist()

plt.figure(figsize = (14, 12))
plt.plot(x, y_lax, color = 'blue', label = '% change of baseline at LAX', linewidth = 1)
# plt.plot(x, y_sfo, color = 'red', label = '% change of baseline over time', linewidth = 1)
# plt.plot(x, y_bos, color = 'yellow', label = '% change of baseline over time', linewidth = 1)
plt.plot(x, y_atl, color = 'cyan', label = '% change of baseline at ATL', linewidth = 1)
plt.plot(x, y_dfw, color = 'black', label = '% change of baseline at DFW', linewidth = 1)

plt.ticklabel_format(axis="y", style="plain")
plt.title('PercentOfBaseline', fontsize = 24, pad = 20)
plt.xlabel('Date')
plt.ylabel('% change of baseline')
plt.legend(loc = 'best')
plt.grid(alpha = 0.75)
plt.show()
